# %% [markdown]
# # ----------------------------------SnowFlakes--------------------------

# %% [markdown]
# ## 1) Difference between Datawarehouse and Datalakes

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ## 2) Why did snowflakes came to picture?

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ## 3) SnowFlakes Architecture

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ## 4) Detailed about compute layer

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ## 5) Detail about storage layer

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# ## 6) What was the issue with hive partitioning

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# ## 7) Let understand the limitations of snowflakes

# %% [markdown]
# ![8.png](attachment:8.png)
